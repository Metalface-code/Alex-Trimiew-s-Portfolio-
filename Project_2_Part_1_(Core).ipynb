# %% [markdown]
# <a href="https://colab.research.google.com/github/Metalface-code/Alex-Trimiew-s-Portfolio-/blob/main/Project_2_Part_1_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Coding Dojo/wines_SPA.csv')
df.head(1)
# Out:
#           winery   wine  year  rating  num_reviews country region  price  \
# 0  Teso La Monja  Tinto  2013     4.9           58  Espana   Toro  995.0
#
#        type  body  acidity
# 0  Toro Red   5.0      3.0

# %% [markdown]
# First choice: dataset 1
#
# 1) Source of data- Kaggle.com
#
# 2) Brief description of data- This dataset is related to red variants of spanish wines. The dataset describes several popularity and description metrics their effect on it's quality.
#
# 3) What is the target? The quility of wine based on price
#
# 4) Is this a classification or regression problem? regression
#
# 5) How many features? 5
#
# 6) How many rows of data. 11
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset? There shouldnt be any chalenges exploring the dataset

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Coding Dojo/mushrooms.csv')
df.head(3)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# ...

# %% [markdown]
# Second choice: dataset 2
#
# 1) Source of data Kaggle.com
#
# 2) Brief description of data mushrooms that are safe or not safe to consume
#
# 3) What is the target? is the mushroom poisonus
#
# 4) Is this a classification or regression problem? classification
#
# 5) How many features? 5
#
# 6) How many rows of data. 23
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset? there will be chalenges with the data in the data set being mostly objects
